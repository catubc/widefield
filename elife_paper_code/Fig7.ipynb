# %%
import matplotlib
#matplotlib.use('Agg')

# %load_ext autoreload
# %autoreload 2

#%matplotlib tk
# %autosave 180

import matplotlib.pyplot as plt
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

import numpy as np
import os

# visualize results module
from visualize import visualize_svm as Visualize
# Out:
# Autosaving every 180 seconds
# <ipython-input-1-23ca53a6ed85>:11: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# <style>.container { width:100% !important; }</style>

# %%
###############################################################
########################## Fig 6a #############################
###############################################################

# Fig 6a - DF/F loingutindal and variance (note different smoothing used from biorxiv version)
root_dir = './data'
animal_id = 'IJ2'
session_ids = ['Feb3_','Mar3_']

#
Visualize.plot_area_averages(root_dir, animal_id, session_ids)

# %%
###############################################################
########################## Fig 7b #############################
###############################################################

# Fig 7b
root_dir = './data'
animal_id = 'IJ2'

#
Visualize.plot_power_spectra_multi_area(root_dir, animal_id)

# %%
###############################################################
########################## Fig 7c #############################
###############################################################

# Fig 7c ; show session averages and trends for both frequency power and peaks in frequency
root_dir = './data'
plot_power = False
plot_freq = True
#
Visualize.plot_peak_frequency_all_animals_all_sessions(root_dir,
                                                      plot_power,
                                                      plot_freq)
#plt.savefig('/home/cat/freq_plots_fig7.svg')
#plt.close()
# Out:
# No handles with labels found to put in legend.
# IA1 0 corr:  (0.19437445256470293, 0.16311624941860392)
# IA1 2 corr:  (0.5394733205882425, 3.068433243245289e-05)
# IA1 3 corr:  (0.5118274742448632, 8.95653628143738e-05)
#
# IA2 0 corr:  (-0.2981575004119056, 0.10328140051384245)
# IA2 2 corr:  (-0.6879678949224832, 1.8951364177999577e-05)
# IA2 3 corr:  (-0.5340621645746129, 0.0019713759242949856)
#
# IA3 0 corr:  (-0.21576947997994214, 0.17545107856797146)
# IA3 2 corr:  (-0.16862557229687303, 0.29192432847158684)
# IA3 3 corr:  (-0.09937351108289118, 0.5364723617416676)
#
# IJ1 0 corr:  (0.31869689220644126, 0.0450375711188844)
# IJ1 2 corr:  (0.26954232900695135, 0.09257479788117409)
# IJ1 3 corr:  (0.10265599662043433, 0.5284757929772151)
#
# IJ2 0 corr:  (0.3550264067412439, 0.026567838607618854)
# IJ2 2 corr:  (0.31209753599995055, 0.05308149187599243)
# IJ2 3 corr:  (0.11267772629395281, 0.4946335122631921)
#
# AQ2 0 corr:  (0.19705950898847968, 0.08583406455828445)
# ...
