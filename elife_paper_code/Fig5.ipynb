# %%
import matplotlib
#matplotlib.use('Agg')

# %load_ext autoreload
# %autoreload 2

#%matplotlib tk
# %autosave 180

import matplotlib.pyplot as plt
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

import numpy as np
import os

# visualize results module
from visualize import visualize_svm as Visualize
# Out:
# Autosaving every 180 seconds
# <ipython-input-1-23ca53a6ed85>:11: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# <style>.container { width:100% !important; }</style>

# %%
###############################################################
########################## Fig 5a,b ###########################
###############################################################

# Fig 5 a, b - DF/F loingutindal and variance (note different smoothing used from biorxiv version)
root_dir = './data'
animal_id = 'IA3'

#
Visualize.plot_all_variances(root_dir, animal_id)

# %%
###############################################################
########################## Fig 5c #############################
###############################################################

# Fig 5c - earliest variance change times (note different filters used than in biorxiv version)
root_dir = './data'
animal_id = 'AQ2'

#
Visualize.plot_first_decay_time(root_dir, animal_id)

#plt.savefig('/home/cat/visual_evdt.svg')
#plt.close()
