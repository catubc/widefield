# %%
import matplotlib
#matplotlib.use('Agg')

# %load_ext autoreload
# %autoreload 2

#%matplotlib tk
# %autosave 180

import matplotlib.pyplot as plt
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

import numpy as np
import os

# visualize results module
from visualize import visualize_svm as Visualize
# Out:
# Autosaving every 180 seconds
# <ipython-input-1-23ca53a6ed85>:11: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# <style>.container { width:100% !important; }</style>

# %%
###############################################################
########################## Fig 6a #############################
###############################################################

# Fig 6a - DF/F loingutindal and variance (note different smoothing used from biorxiv version)
root_dir = './data'

#
Visualize.plot_no_of_hrs_of_recordings_vs_no_of_trials(root_dir)

# %%
###############################################################
########################## Fig 6b #############################
###############################################################

# Fig 6b piecharts
root_dir = './data'
animal_id = 'IA1'

#
Visualize.plot_pie_charts_behaviors(root_dir, animal_id)
# Out:
# 100%|██████████| 53/53 [00:00<00:00, 27797.69it/s]

# %%
###############################################################
########################## Fig 6c #############################
###############################################################
# Fig 6c percentages
root_dir = './data'
animal_ids = ['IA1','IA2','IA3','IJ1','IJ2','AQ2']

#
Visualize.plot_all_animal_lever_pulls_percentages(root_dir, animal_ids)

# %%
###########################################################
######################## Fig 6d ###########################
###########################################################

# Fig 6 d
root_dir = './data'
animal_ids = ['IA1']

#         
Visualize.compute_lockout_single_animal(root_dir,animal_ids)

# %%
###########################################################
######################## Fig 6e ###########################
###########################################################

# Fig 6 e
root_dir = './data'

#
Visualize.plot_all_lockouts_all_animals(root_dir)

# %%
###########################################################
######################## Fig 6g ###########################
###########################################################

# Fig 6 g
root_dir = './data'

#
Visualize.plot_svm_accuracy_with_lockouts(root_dir)
plt.show()


#plt.savefig('/home/cat/12seclockout.svg')
#plt.close()

# %%
###########################################################
######################## Fig 6h ###########################
###########################################################

# Fig 6 g
root_dir = './data'

#
Visualize.plot_trends_lever_lockouts(root_dir)
