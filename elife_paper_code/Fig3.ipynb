# %%
import matplotlib
#matplotlib.use('Agg')

# %load_ext autoreload
# %autoreload 2

#%matplotlib tk
# %autosave 180

import matplotlib.pyplot as plt
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

import numpy as np
import os

# visualize results module
from visualize import visualize_svm as Visualize
# Out:
# Autosaving every 180 seconds
# <style>.container { width:100% !important; }</style>

# %%
##########################################################
####################### Fig 3a ###########################
##########################################################

# Fig 3a single trials + sine fit; note: different animal/session than in eLife paper
data_dir = './data/'
animal_id = 'IJ2'
session_id = 21  # march 3rd session
area_id = 2 # upper limb cortex left

#
t0_phases = Visualize.plot_phases(data_dir, animal_id, session_id, area_id, random_flag=False)

#
t0_phases_random = Visualize.plot_phases(data_dir, animal_id, session_id, area_id, random_flag=True)

# %%
##########################################################
######### FIG 3b - single sessions polar plots ###########
##########################################################

# Fig 3b,c,d,e polar plots
Visualize.plot_polar_plots(t0_phases)

#
Visualize.plot_polar_plots(t0_phases_random)

# %%
#################################################
######### Fig 3g all sessions historams #########
#################################################

# Fig 3g
data_dir = './data/'

#
feat_names = ['_Retrosplenial', '_barrel', '_limb', '_visual','_motor','']
feat_id = 4
    
#
animal_ids = ['IA1','AQ2']  # M1 and M6 from biorxiv manuscript

#
Visualize.plot_histograms_schimdthetal(data_dir, animal_ids, feat_id)

# %%
############################################################
######################## Fig 3 h, i#########################
############################################################
# Fig 3h,i
data_dir = './data/'

#
animal_id = 'AQ2'
random_flag = False
Visualize.plot_all_sessions_polar_plots(data_dir, animal_id, random_flag)
# Out:
# ./data/all_phases_all_trials_AQ2.npy
# AQ2 _Retrosplenial rayleightest test :  0.0 1028.2737296319651
# AQ2 _barrel rayleightest test :  0.0 1294.713526539123
# AQ2 _limb rayleightest test :  0.0 1841.6939055977346
# AQ2 _visual rayleightest test :  3.1041995207462954e-269 603.4992987560049
# AQ2 _motor rayleightest test :  0.0 1727.156162606811
