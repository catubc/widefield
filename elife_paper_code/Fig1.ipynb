# %%
import matplotlib
#matplotlib.use('Agg')

# %load_ext autoreload
# %autoreload 2

#%matplotlib tk
# %autosave 180

import matplotlib.pyplot as plt
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

import numpy as np
import os

# visualize results module
from visualize import visualize_svm as Visualize

from visualize import utils as utils
# Out:
# Autosaving every 180 seconds
# <ipython-input-1-7a115611780c>:11: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# <style>.container { width:100% !important; }</style>

# %%
###################################################################
###################################################################
###################################################################
main_dir = '/media/cat/4TBSSD/yuki/'
animals = ['IA1','IA2','IA3','IJ1','IJ2','AQ2']

# 
fig = plt.figure(figsize=(8,8))
utils.plot_number_04_all_mice_all_sessions_single_plot(main_dir, '04', animals, fig)

plt.savefig('/home/cat/lever_pulls.svg')
plt.close()
#plt.show()
# Out:
# 0  cor:  (-0.2592921028120803, 0.031441765054247735)
# 1  cor:  (0.4143557411271329, 0.006369661504736878)
# 2  cor:  (0.34597307019687135, 0.024812618879399163)
# 3  cor:  (-0.08498743503544053, 0.574410891689166)
# 4  cor:  (0.23503915534689848, 0.13404530326495287)
# 5  cor:  (0.5749876467362204, 6.203778818760361e-11)

# %%
##########################################################
####################### Fig 1e ###########################
##########################################################

# Fig 1e average neural activity
data_dir = './data/'
animal_id = 'IJ1'
session_id = 'IJ1pm_Feb11_30Hz'
random_flag = False
    
# 
fig=plt.figure()
Visualize.plot_RP_and_hilbert_transform(data_dir, animal_id, session_id, random_flag)
if False:
    plt.savefig('/home/cat/new1fe.svg')
    plt.close()
else:
    plt.show()

# %%
############################################################
######################## Fig 1 h ###########################
############################################################

# Fig 1h ; examples of decoding curves
data_dir = './data/'
animal_id = 'IA1'
session_id = 'IA1pm_Feb3_30Hz'
# animal_id = 'IJ2'
# session_id = 'IJ2pm_Mar3_30Hz'

#
Visualize.plot_svm_accuracy(data_dir,animal_id, session_id)
